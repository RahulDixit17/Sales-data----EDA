# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Diwali Sales Data.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
pd.isnull(df).sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
# To check the null value in Amount column with its respective columns, if possibile, we  fill the null values with exact value. 
df[['User_ID',
 'Cust_name',
 'Product_ID',
 'Gender',
 'Age Group',
 'Age',
 'Marital_Status',
 'State',
 'Zone',
 'Occupation',
 'Product_Category',
 'Orders',
 'Amount',
 'Status',
 'unnamed1']][df.Amount.isnull()]
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
list(df)
# Out:
# ['User_ID',
#  'Cust_name',
#  'Product_ID',
#  'Gender',
#  'Age Group',
#  'Age',
#  'Marital_Status',
#  'State',
#  'Zone',
#  'Occupation',
#  'Product_Category',
#  'Orders',
#  'Amount',
#  'Status',
#  'unnamed1']

# %%
df.drop(['Status','unnamed1'],axis=1, inplace=True)

# %%
df.shape
# Out:
# (11239, 13)

# %%
# TO drop the null values
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# To check the datatype of any column
df['Amount'].dtypes
# Out:
# dtype('float64')

# %%
# To change the datatype of any column
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
# To check the columns
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# To rename any column
df.rename(columns={'Cust_name':'Customer_name'},inplace=True)

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ### Below count plot showing the Female purchase count is more than male counterparts.

# %%
x = sns.countplot(x='Gender',data=df)

for i in x.containers:
    x.bar_label(i,color='red')

# %%
df
# Out:
#        User_ID Customer_name Product_ID Gender Age Group  Age  Marital_Status  \
# 8025   1002016     Manibalan  P00249742      M       55+   89               0
# 2589   1002092      Shivangi  P00222242      F       55+   80               1
# 10926  1005431        Sample  P00154742      F       55+   90               0
# 5480   1001772         Weien  P00186142      F       55+   58               1
# 7119   1002069      Cacioppo  P00018442      F       55+   65               0
# ...        ...           ...        ...    ...       ...  ...             ...
# 2378   1005420   Französisch  P00156842      F      0-17   13               0
# 6184   1001928        Ferrer  P00113042      F      0-17   12               0
# 10178  1003780       Roberts  P00102342      M      0-17   17               0
# 1200   1000075           Ted  P00137642      M      0-17   15               0
# 6045   1000119         Roger   P0095842      M      0-17   12               0
#
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount','Orders'].sum().sort_values(by='Amount',ascending=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_16888\1634804460.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sales_gen = df.groupby(['Gender'], as_index=False)['Amount','Orders'].sum().sort_values(by='Amount',ascending=False)

# %%
sales_gen
# Out:
#   Gender    Amount  Orders
# 0      F  74335853   19548
# 1      M  31913276    8433

# %% [markdown]
# ### We can see most of the buyers are females; females total purchasing amount are greater than men.

# %%
# Bar plot:

ax = sns.barplot(x='Gender',y='Amount',data=sales_gen)
for i in ax.containers:
    ax.bar_label(i,color='green')

# %% [markdown]
# ### Different age group order count. Max order given by people of age-groups 26-35 .

# %%
x =sns.countplot(x='Age Group',data=df,hue ='Gender')
plt.ylabel("Orders Count",color='Black')
plt.xlabel("Orders Count",color='Black')

for i in x.containers:`
    x.bar_label(i,color='red')

# %% [markdown]
# # Total amount vs age-group

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by=['Amount'], ascending=False)

sns.barplot(x= 'Age Group',y='Amount',data=sales_age)
# Out:
# <AxesSubplot:xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# # State

# %%
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Total no of orders from top 10 states

sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
# Out:
#                State  Orders
# 14     Uttar Pradesh    4807
# 10       Maharashtra    3810
# 7          Karnataka    3240
# 2              Delhi    2740
# 9     Madhya Pradesh    2252
# 0     Andhra Pradesh    2051
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1066

# %% [markdown]
# ## No of orders from top 10 states

# %%
sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)

plt.figure(figsize=(17,5))

sales_state = sns.barplot(data=sales_state,x='State',y='Orders')
for i in sales_state.containers:
       sales_state.bar_label(i,color='red')
        
        
plt.xlabel("States",color='Green')
plt.ylabel("No of Orders",color='Green')
# Out:
# Text(0, 0.5, 'No of Orders')

# %%
#Total amount vs state from top 10 states

df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
# Out:
#                State    Amount
# 14     Uttar Pradesh  19374968
# 10       Maharashtra  14427543
# 7          Karnataka  13523540
# 2              Delhi  11603818
# 9     Madhya Pradesh   8101142
# 0     Andhra Pradesh   8037146
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3946082

# %% [markdown]
# ### No of amounts collected from top 10 states:

# %%
sales_amount = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

plt.figure(figsize=(17,5))

sales_amount = sns.barplot(x='State',y='Amount',data=sales_amount)

# %% [markdown]
# ## Marital Status

# %% [markdown]
# ### Mostly married people did more shopping.

# %%
plt.figure(figsize=(7,5))
t = sns.countplot(x='Marital_Status',data=df)

for i in t.containers:
     t.bar_label(i)

# %% [markdown]
# ### We can see that most of the buyers are married(0) women and they have high purchasing power.

# %%
sales_amount = df.groupby(['Marital_Status','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)

sns.barplot(data = sales_amount, x ='Marital_Status',y='Amount' ,hue='Gender')
# Out:
# <AxesSubplot:xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# ## Occupation -

# %% [markdown]
# ### Most of the people who gave order, work in IT-Sector

# %%
plt.figure(figsize=(19,5))
x = sns.countplot(x='Occupation', data=df)

for i in x.containers:
     x.bar_label(i)

# %% [markdown]
# ## Occupation vs Amount barplot

# %% [markdown]
# ### From below bar chart we can most of the buyers are working in IT, Healthcare and Aviation sector.

# %%
sales_amount = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

x = sns.barplot(data = sales_amount, x ='Occupation',y='Amount')

# %%
df.columns
# Out:
# Index(['User_ID', 'Customer_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df['Product_Category'].nunique()
# Out:
# 18

# %% [markdown]
# ## Product-catagory count
#
# ### Maximum orders in clothing and apparel.

# %%
plt.figure(figsize=(25,5))
x = sns.countplot(data=df,x='Product_Category')

for i in x.containers:
    
     x.bar_label(i)

# %% [markdown]
# ### Product_Catagory vs Amount

# %% [markdown]
# ### Most of the sold product are from Food, Clothing and Apparel, Electronics&Gadgets

# %%
sales_amount = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
plt.figure(figsize=(20,7))
x = sns.barplot(data = sales_amount, x ='Product_Category',y='Amount')

# %% [markdown]
# ## Most selling products details

# %%
df.groupby(['Product_ID'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
# Out:
#      Product_ID  Amount
# 1679  P00265242  540136
# 644   P00110942  424833
# 1146  P00184942  401816
# 654   P00112142  341020
# 396   P00059442  338571
# 1504  P00237542  322363
# 388   P00058042  307040
# 642   P00110742  294548
# 643   P00110842  290661
# 492   P00080342  283309

# %% [markdown]
# ## Mostly ordered product detail: P00265242 & P00110942

# %%
prod_order = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
plt.figure(figsize=(15,7))
x = sns.barplot(data = prod_order, x ='Product_ID',y='Orders')

for i in x.containers:
    
     x.bar_label(i,color = 'red')

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Avilation sectors are more likely to buy products from food, clothing and electronics catagory.

# %% [markdown]
# Add in Resume:
# In this project we worked on :
# 1. Performed data cleaning and manipulation.
# 2.Performed EDA(Exploratory data analysis) using pandas,matplotlib and seaborn libraries.
# 3.Improved customer experience by identifing potential customers across different states, occupation, Gender and age-groups.
# 4. Improved sales by identifying most selling product catagories and products, which can help to plan inventory and meet the demands.
